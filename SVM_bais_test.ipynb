# %%
# For data management
import pandas as pd
import numpy as np
import pickle

from sklearn import svm
from sklearn import metrics

from sklearn.model_selection import train_test_split

# For plotting
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
pickle_in = open("X_test_POC.pickle", "rb")
X_test_POC = pickle.load(pickle_in)
pickle_in = open("y_test_POC.pickle", "rb")
y_test_POC = pickle.load(pickle_in)

pickle_in = open("X_test_W.pickle", "rb")
X_test_W = pickle.load(pickle_in)
pickle_in = open("y_test_W.pickle", "rb")
y_test_W = pickle.load(pickle_in)

# %%
#load models
pickle_in = open("SVM-50.pkl", "rb")
model_50 = pickle.load(pickle_in)

# %% [markdown]
# # POC TEST

# %% [markdown]
# ## Model trained with 50% dataset

# %%
y_pred = model_50.predict(X_test_POC)
accuracy = model_50.score(X_test_POC, y_test_POC)

# %%
print(metrics.classification_report(y_test_POC, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.02      0.04       100
#            1       0.63      0.93      0.75       102
#            2       0.53      0.76      0.62       107
#
#     accuracy                           0.58       309
#    macro avg       0.52      0.57      0.47       309
# weighted avg       0.52      0.58      0.48       309

# %%
cm = confusion_matrix(y_test_POC, y_pred)

plt.figure(figsize=(9,9))
# Heatmap visualization of accuracy
sns.heatmap(cm,annot=True, fmt='.3f', linewidths=.5, square=True,cmap='Reds_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format(accuracy_score(y_true=y_test_POC, y_pred=y_pred))
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.5760517799352751')

# %% [markdown]
# # WHITE TEST

# %% [markdown]
# ## Model trained with 50% of the dataset

# %%
y_pred = model_50.predict(X_test_W)
accuracy = model_50.score(X_test_W, y_test_W)

# %%
print(metrics.classification_report(y_test_W, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.01      0.02       100
#            1       0.26      0.17      0.21       103
#            2       0.39      0.86      0.53       106
#
#     accuracy                           0.36       309
#    macro avg       0.30      0.35      0.25       309
# weighted avg       0.30      0.36      0.26       309

# %%
cm = confusion_matrix(y_test_W, y_pred)

plt.figure(figsize=(9,9))
# Heatmap visualization of accuracy
sns.heatmap(cm,annot=True, fmt='.3f', linewidths=.5, square=True,cmap='Reds_r')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
all_sample_title = 'Accuracy Score: {0}'.format(accuracy_score(y_true=y_test_W, y_pred=y_pred))
plt.title(all_sample_title,size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score: 0.3559870550161812')
